# %%
import matplotlib.pyplot as plt
import numpy as np

xaxis = np.array([0,6])
yaxis = np.array([0,250])
plt.plot(xaxis, yaxis)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,9])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='o')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

xaxis=np.array([3,9,10,5])
plt.plot(xaxis,marker='*')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([10,8,9,5])
plt.plot(ypoints, marker='.')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker=',')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='x')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='+')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='p')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='s')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='D')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='d')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='X')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='P')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='H')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='h')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='v')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='^')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='<')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='>')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='1')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='2')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='3')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='4')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='|')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='_',ms=20)
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='o',ms=25)
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='o',ms=20,mec='r')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='o',ms=20,mec='g',mfc='r')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='o',ms=20,mec='r',mfc='g')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='o',ms=20,mec='r',mfc='c')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='o',ms=20,mec='r',mfc='m')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='o',ms=20,mec='r',mfc='y')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='o',ms=20,mec='r',mfc='k')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, marker='o',ms=20,mec='r',mfc='w')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

ypoints =np.array([3,8,1,10])
plt.plot(ypoints, 'o:g')
plt.show()

# %%
import matplotlib.pyplot as py
import numpy as np

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid()
plt.show()
# Out:
#   Input In [48]
#     x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
#                      ^
# SyntaxError: invalid non-printable character U+00A0

# %%
import matplotlib.pyplot as py
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()
# Out:
#   Input In [51]
#     import matplotlib.pyplot as py
#           ^
# SyntaxError: invalid non-printable character U+00A0

# %%
#Creating Bars using bar()
import matplotlib.pyplot as py
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
plt.show()
# Out:
#   Input In [53]
#     import matplotlib.pyplot as py
#           ^
# SyntaxError: invalid non-printable character U+00A0

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()
# Out:
#   Input In [54]
#     import matplotlib.pyplot as plt
#           ^
# SyntaxError: invalid non-printable character U+00A0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5], hist=True)

plt.show()
# Out:
# C:\Users\venkata sai\AppData\Local\Temp\ipykernel_2496\786514785.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=True)

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
df= pd.read_csv('salary.csv')
print(df)
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
df= pd.read_csv('salary.csv')
sns.lineplot(x='YearsExperience',y='Salary',data=df,marker='o')
plt.show()

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
df= pd.read_csv('salary.csv')
sns.barplot(x='YearsExperience',y='Salary',data=df)
plt.show()
